# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {
               'n_estimators':[50,100],
               'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
               'max_features':['sqrt', 'log2', None]
               }
grid = GridSearchCV(RandomForestRegressor(), param_grid, n_jobs=-1, refit=True,cv=5, verbose=3)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
y_pred = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score= r2_score(y_test, y_pred)
print("r_score{}".format(grid.best_params_), r_score)
# Out:
# r_score{'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100} 0.8723676314607233

# %%
re = grid.cv_results_
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.263137      0.033263         0.015493        0.004521
# 1        0.494579      0.038691         0.023096        0.001640
# 2        0.249486      0.036547         0.017751        0.003938
# 3        0.432120      0.010484         0.028554        0.003420
# 4        0.277003      0.006121         0.014680        0.004306
# 5        0.521077      0.024125         0.023365        0.004248
# 6        0.591076      0.035667         0.014665        0.003806
# 7        1.137548      0.070463         0.020631        0.001827
# 8        0.558789      0.015966         0.012084        0.002775
# 9        1.142449      0.046661         0.018565        0.005031
# 10       0.932167      0.016474         0.009567        0.001043
# 11       2.011574      0.080540         0.023004        0.004229
# 12       0.218759      0.008338         0.012327        0.002199
# 13       0.409784      0.011784         0.020928        0.001309
# 14       0.216357      0.012124         0.015845        0.004698
# 15       0.433888      0.004961         0.021411        0.002207
# 16       0.271298      0.010182         0.010131        0.000275
# 17       0.557525      0.011179         0.019438        0.003123
# 18       0.244922      0.008114         0.013153        0.001822
# 19       0.488241      0.008944         0.021043        0.003236
# 20       0.239013      0.003688         0.012840        0.004079
# 21       0.475860      0.017998         0.019192        0.001747
# 22       0.304423      0.004457         0.014706        0.004553
# 23       0.526434      0.047805         0.014707        0.003550
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 50
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 50
# 3    squared_error               log2                100
# 4    squared_error               None                 50
# 5    squared_error               None                100
# 6   absolute_error               sqrt                 50
# 7   absolute_error               sqrt                100
# 8   absolute_error               log2                 50
# 9   absolute_error               log2                100
# 10  absolute_error               None                 50
# 11  absolute_error               None                100
# 12    friedman_mse               sqrt                 50
# 13    friedman_mse               sqrt                100
# 14    friedman_mse               log2                 50
# 15    friedman_mse               log2                100
# 16    friedman_mse               None                 50
# 17    friedman_mse               None                100
# 18         poisson               sqrt                 50
# 19         poisson               sqrt                100
# 20         poisson               log2                 50
# 21         poisson               log2                100
# 22         poisson               None                 50
# 23         poisson               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.869839
# 1   {'criterion': 'squared_error', 'max_features':...           0.863023
# 2   {'criterion': 'squared_error', 'max_features':...           0.864596
# 3   {'criterion': 'squared_error', 'max_features':...           0.856647
# 4   {'criterion': 'squared_error', 'max_features':...           0.858779
# 5   {'criterion': 'squared_error', 'max_features':...           0.863086
# 6   {'criterion': 'absolute_error', 'max_features'...           0.856523
# 7   {'criterion': 'absolute_error', 'max_features'...           0.860342
# 8   {'criterion': 'absolute_error', 'max_features'...           0.848867
# 9   {'criterion': 'absolute_error', 'max_features'...           0.863022
# 10  {'criterion': 'absolute_error', 'max_features'...           0.853554
# 11  {'criterion': 'absolute_error', 'max_features'...           0.847566
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0