# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {
               'n_estimators':[50,100],
               'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
               'max_features':['sqrt', 'log2', None]
               }
grid = GridSearchCV(RandomForestRegressor(), param_grid, n_jobs=-1, refit=True,cv=5, verbose=3)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
y_pred = grid.predict(independent)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(dependent, y_pred)
print("r_score{}".format(grid.best_params_),r_score)
# Out:
# r_score{'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100} 0.976128431247533

# %%
re = grid.cv_results_
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.316790      0.003926         0.015811        0.004833
# 1        0.580210      0.008197         0.030364        0.002986
# 2        0.283259      0.023054         0.013743        0.002458
# 3        0.509370      0.009019         0.024740        0.005111
# 4        0.336296      0.008885         0.014497        0.004507
# 5        0.648298      0.004060         0.023008        0.002321
# 6        0.866424      0.017796         0.010214        0.003649
# 7        1.825013      0.048420         0.028073        0.005191
# 8        0.893508      0.028860         0.016944        0.004289
# 9        2.008703      0.070710         0.022836        0.003684
# 10       1.774781      0.012336         0.014723        0.004270
# 11       3.715209      0.052307         0.025517        0.004258
# 12       0.306956      0.012280         0.014509        0.004210
# 13       0.635309      0.024534         0.030621        0.006111
# 14       0.319470      0.010883         0.015874        0.006282
# 15       0.615611      0.010515         0.026906        0.005023
# 16       0.391956      0.011379         0.021503        0.005661
# 17       0.770134      0.016327         0.031841        0.007543
# 18       0.346093      0.009209         0.018715        0.005275
# 19       0.738197      0.018524         0.035381        0.006715
# 20       0.358409      0.007289         0.017385        0.003705
# 21       0.694147      0.005844         0.024022        0.005883
# 22       0.474015      0.006963         0.019132        0.002207
# 23       0.617725      0.088073         0.014697        0.002958
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 50
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 50
# 3    squared_error               log2                100
# 4    squared_error               None                 50
# 5    squared_error               None                100
# 6   absolute_error               sqrt                 50
# 7   absolute_error               sqrt                100
# 8   absolute_error               log2                 50
# 9   absolute_error               log2                100
# 10  absolute_error               None                 50
# 11  absolute_error               None                100
# 12    friedman_mse               sqrt                 50
# 13    friedman_mse               sqrt                100
# 14    friedman_mse               log2                 50
# 15    friedman_mse               log2                100
# 16    friedman_mse               None                 50
# 17    friedman_mse               None                100
# 18         poisson               sqrt                 50
# 19         poisson               sqrt                100
# 20         poisson               log2                 50
# 21         poisson               log2                100
# 22         poisson               None                 50
# 23         poisson               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.855686
# 1   {'criterion': 'squared_error', 'max_features':...           0.855482
# 2   {'criterion': 'squared_error', 'max_features':...           0.853184
# 3   {'criterion': 'squared_error', 'max_features':...           0.859571
# 4   {'criterion': 'squared_error', 'max_features':...           0.846902
# 5   {'criterion': 'squared_error', 'max_features':...           0.847460
# 6   {'criterion': 'absolute_error', 'max_features'...           0.858214
# 7   {'criterion': 'absolute_error', 'max_features'...           0.856589
# 8   {'criterion': 'absolute_error', 'max_features'...           0.850211
# 9   {'criterion': 'absolute_error', 'max_features'...           0.857257
# 10  {'criterion': 'absolute_error', 'max_features'...           0.836636
# 11  {'criterion': 'absolute_error', 'max_features'...           0.835330
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.855019
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.854057
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.850137
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.859753
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.845643
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.848950
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.854048
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.857541
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.860367
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.860137
# 22  {'criterion': 'poisson', 'max_features': None,...           0.843729
# 23  {'criterion': 'poisson', 'max_features': None,...           0.841849
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.777183           0.855250           0.825651
# 1            0.775937           0.859080           0.829423
# 2            0.781476           0.851378           0.826064
# 3            0.782020           0.862448           0.829407
# 4            0.769900           0.852612           0.818237
# 5            0.776876           0.855645           0.820565
# 6            0.778630           0.854072           0.827450
# 7            0.779155           0.857549           0.823642
# 8            0.776129           0.858015           0.828677
# 9            0.783140           0.855278           0.826344
# 10           0.767434           0.851177           0.821717
# 11           0.771683           0.856625           0.820847
# 12           0.777597           0.859021           0.829812
# 13           0.785983           0.862132           0.827159
# 14           0.772878           0.854861           0.831518
# 15           0.777929           0.863401           0.828497
# 16           0.773710           0.852701           0.819231
# 17           0.769040           0.854978           0.817698
# 18           0.775835           0.862620           0.823917
# 19           0.777078           0.859752           0.830494
# 20           0.781076           0.860884           0.821002
# 21           0.779387           0.860956           0.827388
# 22           0.765658           0.861658           0.818141
# 23           0.773283           0.858985           0.817957
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.838490         0.830452        0.028903               14
# 1            0.838925         0.831769        0.029940                9
# 2            0.840561         0.830532        0.026362               13
# 3            0.841775         0.835044        0.029125                1
# 4            0.838609         0.825252        0.030029               21
# 5            0.839175         0.827944        0.028060               17
# 6            0.841085         0.831890        0.028726                8
# 7            0.845034         0.832394        0.029288                7
# 8            0.840900         0.830787        0.029027               12
# 9            0.846701         0.833744        0.027568                4
# 10           0.831091         0.821611        0.028723               24
# 11           0.834685         0.823834        0.028474               23
# 12           0.835655         0.831421        0.029107               10
# 13           0.841677         0.834201        0.026851                2
# 14           0.839754         0.829829        0.029610               15
# 15           0.839484         0.833813        0.030763                3
# 16           0.839004         0.826058        0.028453               19
# 17           0.831822         0.824498        0.030667               22
# 18           0.830492         0.829382        0.030369               16
# 19           0.842085         0.833390        0.030111                5
# 20           0.833408         0.831347        0.029506               11
# 21           0.838613         0.833296        0.029849                6
# 22           0.842933         0.826424        0.033390               18
# 23           0.836756         0.825766        0.029320               20

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 45
# BMI: 30
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
Future_Prediction
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([9935.8714448])
