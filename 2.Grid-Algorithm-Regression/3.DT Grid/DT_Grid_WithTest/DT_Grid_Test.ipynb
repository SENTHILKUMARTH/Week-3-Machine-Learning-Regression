# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
              'splitter':['best', 'random'],
              'max_features':['sqrt','log2','None']
             }
grid =  GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose=3, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 23 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 17 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'None' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.58357613 0.60708006 0.69147667 0.58687145        nan        nan
#  0.64381437 0.58473765 0.64780512 0.60853484        nan        nan
#  0.6203839  0.59529889 0.61264053 0.62838544        nan        nan
#  0.61302318 0.52577117 0.57060814 0.60137545        nan        nan]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', 'None'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test, grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}: 0.7199163949297875

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.021551      0.020251         0.014728        0.005685
# 1        0.009187      0.001037         0.010172        0.007137
# 2        0.011883      0.003197         0.011772        0.012147
# 3        0.014984      0.008521         0.010046        0.005339
# 4        0.001104      0.002208         0.000000        0.000000
# 5        0.002637      0.003939         0.000000        0.000000
# 6        0.014426      0.012059         0.008133        0.007775
# 7        0.011906      0.002701         0.010164        0.007365
# 8        0.011694      0.003738         0.009636        0.005986
# 9        0.010792      0.003152         0.005067        0.002588
# 10       0.001843      0.002234         0.000000        0.000000
# 11       0.000241      0.000482         0.000000        0.000000
# 12       0.034352      0.009970         0.010145        0.005471
# 13       0.024626      0.006481         0.015830        0.009741
# 14       0.049656      0.019837         0.013507        0.009733
# 15       0.025688      0.003753         0.003676        0.002787
# 16       0.002219      0.003152         0.000000        0.000000
# 17       0.004566      0.003598         0.000000        0.000000
# 18       0.018281      0.004148         0.006804        0.002054
# 19       0.011818      0.001980         0.005668        0.003178
# 20       0.015263      0.004685         0.005285        0.004906
# 21       0.008125      0.004639         0.006979        0.004392
# 22       0.004419      0.005446         0.000000        0.000000
# 23       0.002738      0.003660         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6     friedman_mse               sqrt           best
# 7     friedman_mse               sqrt         random
# 8     friedman_mse               log2           best
# 9     friedman_mse               log2         random
# 10    friedman_mse               None           best
# 11    friedman_mse               None         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
# 16  absolute_error               None           best
# 17  absolute_error               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.722699
# 1   {'criterion': 'squared_error', 'max_features':...           0.645087
# 2   {'criterion': 'squared_error', 'max_features':...           0.714180
# 3   {'criterion': 'squared_error', 'max_features':...           0.719456
# 4   {'criterion': 'squared_error', 'max_features':...                NaN
# 5   {'criterion': 'squared_error', 'max_features':...                NaN
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.695700
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.616614
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.717593
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.751491
# 10  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 11  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 12  {'criterion': 'absolute_error', 'max_features'...           0.658058
# 13  {'criterion': 'absolute_error', 'max_features'...           0.528495
# 14  {'criterion': 'absolute_error', 'max_features'...           0.716995
# 15  {'criterion': 'absolute_error', 'max_features'...           0.710000
# 16  {'criterion': 'absolute_error', 'max_features'...                NaN
# 17  {'criterion': 'absolute_error', 'max_features'...                NaN
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.617886
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.624200
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.654459
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.682423
# 22  {'criterion': 'poisson', 'max_features': 'None...                NaN
# 23  {'criterion': 'poisson', 'max_features': 'None...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.613653           0.550321           0.616779
# 1            0.606236           0.651260           0.534652
# 2            0.675555           0.672017           0.676268
# 3            0.565591           0.589162           0.475724
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6            0.621595           0.573597           0.579287
# 7            0.633927           0.620745           0.485227
# 8            0.660201           0.629378           0.590307
# 9            0.517998           0.648081           0.501280
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12           0.668946           0.699341           0.537178
# 13           0.564585           0.647681           0.638666
# 14           0.482260           0.629295           0.600870
# 15           0.614114           0.682232           0.506557
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18           0.584661           0.663480           0.522546
# 19           0.556357           0.377942           0.596849
# 20           0.611076           0.423109           0.499665
# 21           0.600439           0.569263           0.600382
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.414429         0.583576        0.101073               14
# 1            0.598165         0.607080        0.041767                9
# 2            0.719364         0.691477        0.020768                1
# 3            0.584423         0.586871        0.077970               12
# 4                 NaN              NaN             NaN               17
# 5                 NaN              NaN             NaN               17
# 6            0.748893         0.643814        0.068296                3
# 7            0.567175         0.584738        0.054668               13
# 8            0.641548         0.647805        0.041734                2
# 9            0.623824         0.608535        0.091580                8
# 10                NaN              NaN             NaN               17
# 11                NaN              NaN             NaN               17
# 12           0.538396         0.620384        0.068785                5
# 13           0.597069         0.595299        0.044797               11
# 14           0.633783         0.612641        0.075831                7
# 15           0.629025         0.628385        0.070152                4
# 16                NaN              NaN             NaN               17
# 17                NaN              NaN             NaN               17
# 18           0.676543         0.613023        0.055848                6
# 19           0.473508         0.525771        0.089734               16
# 20           0.664731         0.570608        0.094145               15
# 21           0.554370         0.601375        0.044297               10
# 22                NaN              NaN             NaN               17
# 23                NaN              NaN             NaN               17

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 35
# BMI: 20
# Children: 3
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
future_prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(future_prediction))
# Out:
# Future_Prediction=[6414.178]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename = "Deploy_DT_Grid_Test.sav"

# %%
pickle.dump(grid, open(filename,'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
result = loaded_model.predict([[35, 20, 3, 0,0]])
result
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([6414.178])
