# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset,dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=True)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param_grid= {
            'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
            'splitter': ['best', 'random'],
            'max_features':['sqrt', 'log2']
            }
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, n_jobs=-1,refit=True,cv=5, verbose=3)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_pred = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test, grid_pred)
print("r_score{}".format(grid.best_params_),r_score)
# Out:
# r_score{'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'} 0.6971355973954283

# %%
re = grid.cv_results_
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.012372      0.004263         0.004153        0.003003
# 1        0.010464      0.003434         0.004900        0.004441
# 2        0.012761      0.002255         0.005510        0.003308
# 3        0.008272      0.002632         0.003432        0.004243
# 4        0.007663      0.002161         0.004816        0.000913
# 5        0.007009      0.002773         0.006805        0.002093
# 6        0.007492      0.001877         0.001840        0.003013
# 7        0.007727      0.004741         0.005423        0.003849
# 8        0.021068      0.002308         0.006739        0.002959
# 9        0.017429      0.005355         0.005991        0.003925
# 10       0.021116      0.002865         0.004903        0.001142
# 11       0.016847      0.001926         0.004133        0.000589
# 12       0.010444      0.002237         0.006122        0.001839
# 13       0.007005      0.001284         0.004254        0.001154
# 14       0.008160      0.000310         0.003480        0.001449
# 15       0.005484      0.001653         0.004350        0.002175
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.410465
# 1   {'criterion': 'squared_error', 'max_features':...           0.649552
# 2   {'criterion': 'squared_error', 'max_features':...           0.680625
# 3   {'criterion': 'squared_error', 'max_features':...           0.600156
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.646456
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.573916
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.424216
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.405119
# 8   {'criterion': 'absolute_error', 'max_features'...           0.349421
# 9   {'criterion': 'absolute_error', 'max_features'...           0.611579
# 10  {'criterion': 'absolute_error', 'max_features'...           0.369665
# 11  {'criterion': 'absolute_error', 'max_features'...           0.638612
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.632872
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.670227
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.601275
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.593058
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.650577           0.614807           0.642534
# 1            0.661914           0.614312           0.662560
# 2            0.706023           0.638634           0.384343
# 3            0.674752           0.624183           0.416560
# 4            0.732974           0.576134           0.670162
# 5            0.639788           0.619530           0.570654
# 6            0.688933           0.652345           0.637385
# 7            0.685619           0.497390           0.586891
# 8            0.590657           0.647882           0.625526
# 9            0.672860           0.419963           0.631292
# 10           0.710169           0.613343           0.502750
# 11           0.813811           0.615942           0.606154
# 12           0.755270           0.457969           0.605640
# 13           0.667956           0.594927           0.646838
# 14           0.677105           0.653440           0.650280
# 15           0.544568           0.553215           0.618512
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.809990         0.625675        0.127522                9
# 1            0.777171         0.673102        0.054914                3
# 2            0.763592         0.634643        0.131532                5
# 3            0.643839         0.591898        0.091013               13
# 4            0.785971         0.682339        0.072137                1
# 5            0.751997         0.631177        0.065953                8
# 6            0.753378         0.631251        0.110985                7
# 7            0.676094         0.570223        0.107114               16
# 8            0.717582         0.586214        0.125456               14
# 9            0.743003         0.615739        0.107747               10
# 10           0.708580         0.580901        0.130225               15
# 11           0.727500         0.680404        0.079285                2
# 12           0.586408         0.607632        0.095171               11
# 13           0.579293         0.631848        0.037753                6
# 14           0.706337         0.657687        0.034638                4
# 15           0.728286         0.607528        0.066070               12

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 45
# BMI: 30
# Children: 3
# Sex Male 0 or 1: 2
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
Future_Prediction
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([22478.6])
