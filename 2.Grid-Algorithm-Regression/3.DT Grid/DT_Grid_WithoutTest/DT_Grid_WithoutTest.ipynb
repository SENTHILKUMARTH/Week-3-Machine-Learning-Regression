# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param_grid= {
            'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
            'splitter': ['best', 'random'],
            'max_features':['sqrt', 'log2']
            }
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, n_jobs=-1,refit=True, cv=5, verbose=3)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
y_pred = grid.predict(independent)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(dependent, y_pred)
print("r_score{}".format(grid.best_params_),r_score)
# Out:
# r_score{'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'} 0.998667156135576

# %%
re = grid.cv_results_
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.015943      0.002649         0.007168        0.004041
# 1        0.014755      0.003403         0.005913        0.004520
# 2        0.010485      0.003010         0.007449        0.002546
# 3        0.011010      0.002386         0.003641        0.003552
# 4        0.011404      0.004342         0.004663        0.002619
# 5        0.010067      0.001734         0.002187        0.004374
# 6        0.008600      0.004589         0.006140        0.004321
# 7        0.005519      0.002886         0.005071        0.004903
# 8        0.034376      0.006085         0.004570        0.002386
# 9        0.025969      0.002138         0.003167        0.002590
# 10       0.029402      0.004333         0.006097        0.003792
# 11       0.023414      0.001762         0.006255        0.005710
# 12       0.013121      0.002319         0.005478        0.002743
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 45
# BMI: 30
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
Future_Prediction
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([8410.04685])

# %%
import pickle
filename = "Save_DT_Grid.sav"

# %%
pickle.dump(grid, open(filename,'wb'))

# %%
result = pickle.load(open(filename,'rb'))

# %%
result.predict([[45,30,2,1,0]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([8410.04685])
