# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
param_grid = {
                'kernel':['rbf', 'sigmoid', 'linear'],
                'C':[10,100,1000,2000],
                'gamma':['auto','scale']
             }
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose=3, n_jobs=-1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.191883      0.020466         0.076689        0.005913      10
# 1        0.147466      0.014165         0.024164        0.004068      10
# 2        0.158972      0.021274         0.024880        0.003700      10
# 3        0.171488      0.011774         0.078758        0.011873      10
# 4        0.196375      0.017751         0.035185        0.002155      10
# 5        0.174585      0.019858         0.023416        0.003951      10
# 6        0.182845      0.015531         0.075001        0.006141     100
# 7        0.127248      0.005183         0.028090        0.003240     100
# 8        0.289379      0.008603         0.022356        0.003859     100
# 9        0.163230      0.012215         0.070731        0.004469     100
# 10       0.182152      0.008709         0.035571        0.003796     100
# 11       0.280616      0.008946         0.024146        0.007502     100
# 12       0.187471      0.003438         0.076179        0.010067    1000
# 13       0.126976      0.005080         0.021646        0.005597    1000
# 14       1.016154      0.112652         0.021733        0.005009    1000
# 15       0.170716      0.018219         0.078463        0.009647    1000
# 16       0.182986      0.009334         0.036393        0.004231    1000
# 17       1.015682      0.119501         0.027149        0.003727    1000
# 18       0.255370      0.029687         0.073816        0.005724    2000
# 19       0.133425      0.010878         0.029725        0.006623    2000
# 20       1.901000      0.153833         0.028958        0.003612    2000
# 21       0.173304      0.001892         0.075277        0.006372    2000
# 22       0.176419      0.005976         0.041264        0.004196    2000
# 23       1.889699      0.082155         0.018927        0.005335    2000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto      sigmoid
# 2         auto       linear
# 3        scale          rbf
# 4        scale      sigmoid
# 5        scale       linear
# 6         auto          rbf
# 7         auto      sigmoid
# 8         auto       linear
# 9        scale          rbf
# 10       scale      sigmoid
# 11       scale       linear
# 12        auto          rbf
# 13        auto      sigmoid
# 14        auto       linear
# 15       scale          rbf
# 16       scale      sigmoid
# 17       scale       linear
# 18        auto          rbf
# 19        auto      sigmoid
# 20        auto       linear
# 21       scale          rbf
# 22       scale      sigmoid
# 23       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.113791
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.018943
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.110409
# 4    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.116743
# 5     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.018943
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}          -0.100012
# 7    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.559313
# 9       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.160182
# 10  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.142455
# 11   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.559313
# 12      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.080692
# 13  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 14   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.736398
# 15     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.155430
# 16  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -2.043140
# 17  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.736398
# 18      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.033126
# 19  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 20   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.682349
# 21     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.143510
# 22  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -7.209317
# 23  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.682349
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.110741          -0.079156          -0.103389
# 1           -0.113567          -0.081608          -0.106067
# 2            0.029886           0.022167           0.003112
# 3           -0.097459          -0.074488          -0.099597
# 4           -0.119312          -0.085214          -0.108210
# 5            0.029886           0.022167           0.003112
# 6           -0.098456          -0.072981          -0.096615
# 7           -0.113567          -0.081608          -0.106067
# 8            0.521798           0.547691           0.538805
# 9           -0.107253          -0.123430          -0.137753
# 10          -0.160831          -0.117544          -0.137984
# 11           0.521798           0.547691           0.538805
# 12          -0.054347          -0.062876          -0.079329
# 13          -0.113567          -0.081608          -0.106067
# 14           0.675162           0.680002           0.699377
# 15          -0.098267          -0.123724          -0.137137
# 16          -2.686121          -2.194563          -2.210858
# 17           0.675162           0.680002           0.699377
# 18          -0.002835          -0.026545          -0.029140
# 19          -0.113567          -0.081608          -0.106067
# 20           0.630642           0.750714           0.646368
# 21          -0.087595          -0.113312          -0.128591
# 22          -9.282940          -7.776578          -7.745074
# 23           0.630642           0.750714           0.646368
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.106488        -0.102713        0.012303               13
# 1           -0.107195        -0.104753        0.012107               14
# 2           -0.066653        -0.006086        0.034672                7
# 3           -0.124428        -0.101276        0.016459               12
# 4           -0.108716        -0.107639        0.012029               18
# 5           -0.066653        -0.006086        0.034672                7
# 6           -0.102232        -0.094059        0.010699               11
# 7           -0.107195        -0.104753        0.012107               14
# 8            0.508518         0.535225        0.018122                5
# 9           -0.209551        -0.147634        0.035511               22
# 10          -0.130402        -0.137843        0.014263               20
# 11           0.508518         0.535225        0.018122                5
# 12          -0.117983        -0.079045        0.021865               10
# 13          -0.107195        -0.104753        0.012107               14
# 14           0.677952         0.693778        0.022955                1
# 15          -0.206405        -0.144193        0.036262               21
# 16          -1.942521        -2.215441        0.255409               23
# 17           0.677952         0.693778        0.022955                1
# 18          -0.067392        -0.031808        0.020699                9
# 19          -0.107195        -0.104753        0.012107               14
# 20           0.722261         0.686467        0.045056                3
# 21          -0.193992        -0.133400        0.035492               19
# 22          -6.891719        -7.781126        0.821557               24
# 23           0.722261         0.686467        0.045056                3

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 24
# BMI: 32
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
Future_Prediction
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([3651.44921432])

# %%
import pickle
filename = "Deploy_SVR_Without_test"

# %%
pickle.dump(grid, open(filename,'wb'))

# %%
loaded_model = pickle.load(open(filename,'rb'))

# %%
result = loaded_model.predict([[35,40,2,0,0]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([6781.43409107])
