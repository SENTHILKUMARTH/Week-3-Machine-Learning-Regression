# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first = True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 0.30, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
param_grid = {
                'fit_intercept':[True, False],
                'copy_X':[True, False],
                'n_jobs': [None, 1, -1],
                'positive':[False, True]
             }
grid = GridSearchCV(LinearRegression(), param_grid, n_jobs=-1, refit=True, cv=5, verbose=3)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=LinearRegression(), n_jobs=-1,
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'n_jobs': [None, 1, -1], 'positive': [False, True]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test, grid_pred)
print("r2_score {}".format(grid.best_params_),r_score)
# Out:
# r2_score {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': True} 0.7894790349867009

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_copy_X  \
# 0        0.028510      0.003628         0.005980        0.002275         True
# 1        0.031334      0.005889         0.004567        0.003271         True
# 2        0.020945      0.012838         0.001009        0.002017         True
# 3        0.009592      0.005110         0.006968        0.004212         True
# 4        0.007043      0.002974         0.003904        0.004085         True
# 5        0.041334      0.006660         0.002772        0.000268         True
# 6        0.004471      0.003780         0.008053        0.004229         True
# 7        0.011753      0.002318         0.004001        0.002466         True
# 8        0.006925      0.002142         0.003737        0.001663         True
# 9        0.002625      0.002786         0.006909        0.005700         True
# 10       0.007689      0.003198         0.004568        0.001627         True
# 11       0.032415      0.003802         0.004577        0.002516         True
# 12       0.007614      0.002274         0.005020        0.001643        False
# 13       0.006934      0.002688         0.005467        0.001673        False
# 14       0.006299      0.001982         0.005376        0.001697        False
# 15       0.008845      0.002494         0.002259        0.002497        False
# 16       0.005496      0.001076         0.004624        0.003209        False
# 17       0.030624      0.001261         0.003962        0.001791        False
# 18       0.008011      0.005118         0.003963        0.004634        False
# 19       0.007547      0.002286         0.003139        0.002387        False
# 20       0.005594      0.000678         0.004093        0.002610        False
# 21       0.006459      0.003540         0.004517        0.004717        False
# 22       0.007981      0.003762         0.000535        0.001070        False
# 23       0.025907      0.003502         0.001065        0.001461        False
#
#    param_fit_intercept param_n_jobs param_positive  \
# 0                 True         None          False
# 1                 True         None           True
# 2                 True            1          False
# 3                 True            1           True
# 4                 True           -1          False
# 5                 True           -1           True
# 6                False         None          False
# 7                False         None           True
# 8                False            1          False
# 9                False            1           True
# 10               False           -1          False
# 11               False           -1           True
# 12                True         None          False
# 13                True         None           True
# 14                True            1          False
# 15                True            1           True
# 16                True           -1          False
# 17                True           -1           True
# 18               False         None          False
# 19               False         None           True
# 20               False            1          False
# 21               False            1           True
# 22               False           -1          False
# 23               False           -1           True
#
#                                                params  split0_test_score  \
# 0   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 1   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 2   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 3   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 4   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 5   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 6   {'copy_X': True, 'fit_intercept': False, 'n_jo...           0.744435
# 7   {'copy_X': True, 'fit_intercept': False, 'n_jo...           0.743115
# 8   {'copy_X': True, 'fit_intercept': False, 'n_jo...           0.744435
# 9   {'copy_X': True, 'fit_intercept': False, 'n_jo...           0.743115
# 10  {'copy_X': True, 'fit_intercept': False, 'n_jo...           0.744435
# 11  {'copy_X': True, 'fit_intercept': False, 'n_jo...           0.743115
# 12  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 13  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 14  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 15  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 16  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 17  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 18  {'copy_X': False, 'fit_intercept': False, 'n_j...           0.744435
# 19  {'copy_X': False, 'fit_intercept': False, 'n_j...           0.743115
# 20  {'copy_X': False, 'fit_intercept': False, 'n_j...           0.744435
# 21  {'copy_X': False, 'fit_intercept': False, 'n_j...           0.743115
# 22  {'copy_X': False, 'fit_intercept': False, 'n_j...           0.744435
# 23  {'copy_X': False, 'fit_intercept': False, 'n_j...           0.743115
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.702938           0.730655           0.695551
# 1            0.703146           0.730655           0.695634
# 2            0.702938           0.730655           0.695551
# 3            0.703146           0.730655           0.695634
# 4            0.702938           0.730655           0.695551
# 5            0.703146           0.730655           0.695634
# 6            0.657009           0.700806           0.657076
# 7            0.657160           0.699508           0.657341
# 8            0.657009           0.700806           0.657076
# 9            0.657160           0.699508           0.657341
# 10           0.657009           0.700806           0.657076
# 11           0.657160           0.699508           0.657341
# 12           0.702938           0.730655           0.695551
# 13           0.703146           0.730655           0.695634
# 14           0.702938           0.730655           0.695551
# 15           0.703146           0.730655           0.695634
# 16           0.702938           0.730655           0.695551
# 17           0.703146           0.730655           0.695634
# 18           0.657009           0.700806           0.657076
# 19           0.657160           0.699508           0.657341
# 20           0.657009           0.700806           0.657076
# 21           0.657160           0.699508           0.657341
# 22           0.657009           0.700806           0.657076
# 23           0.657160           0.699508           0.657341
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.719087         0.722348        0.023954                7
# 1            0.719080         0.722405        0.023902                1
# 2            0.719087         0.722348        0.023954                7
# 3            0.719080         0.722405        0.023902                1
# 4            0.719087         0.722348        0.023954                7
# 5            0.719080         0.722405        0.023902                1
# 6            0.686170         0.689099        0.032444               13
# 7            0.684679         0.688361        0.031848               19
# 8            0.686170         0.689099        0.032444               13
# 9            0.684679         0.688361        0.031848               19
# 10           0.686170         0.689099        0.032444               13
# 11           0.684679         0.688361        0.031848               19
# 12           0.719087         0.722348        0.023954                7
# 13           0.719080         0.722405        0.023902                1
# 14           0.719087         0.722348        0.023954                7
# 15           0.719080         0.722405        0.023902                1
# 16           0.719087         0.722348        0.023954                7
# 17           0.719080         0.722405        0.023902                1
# 18           0.686170         0.689099        0.032444               13
# 19           0.684679         0.688361        0.031848               19
# 20           0.686170         0.689099        0.032444               13
# 21           0.684679         0.688361        0.031848               19
# 22           0.686170         0.689099        0.032444               13
# 23           0.684679         0.688361        0.031848               19

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 45
# BMI: 30
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
Future_Prediction
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[10095.06444384]])
